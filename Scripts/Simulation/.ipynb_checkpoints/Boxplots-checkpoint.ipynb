# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

obs = [100, 200, 400, 800, 1600, 3200]

# %% [markdown]
# # 1. Step 1

# %%
step1 = {i: pd.read_csv(f'Estimates {i}x25\\step1.csv') for i in obs}

# %% [markdown]
# # $\alpha$

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([step1[i].alpha_NL for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([step1[i].alpha_NL_XGB for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL_XGB) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([step1[i].alpha_NL_log for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL_log) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(-2, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{α}$')
plt.title('Panel A: α estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel A: α estimates')

# %% [markdown]
# # $\rho$

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([step1[i].rho_NL for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].rho_NL) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([step1[i].rho_NL_XGB for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].rho_NL_XGB) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([step1[i].rho_NL_log for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].rho_NL_log) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(0.3, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.axhline(1, color = 'grey', linewidth = 0.5)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]],
           ['Linear model', 'Log model', 'Flexible model'],
           loc = 'center right')
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{ρ}$')
plt.title('Panel B: ρ estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel B: ρ estimates')

# %% [markdown]
# # $\frac{\alpha}{1 - \rho}$

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([step1[i].alpha_NL  / (1 - step1[i].rho_NL) for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL  / (1 - step1[i].rho_NL)) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([step1[i].alpha_NL_XGB  / (1 - step1[i].rho_NL_XGB) for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL_XGB  / (1 - step1[i].rho_NL_XGB)) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([step1[i].alpha_NL_log  / (1 - step1[i].rho_NL_log) for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(step1[i].alpha_NL_log  / (1 - step1[i].rho_NL_log)) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.ylim(-4.8, -1.0)
plt.axhline(-2 / 0.7, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])

plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{α}$ / (1 - $\hat{ρ}$)')
plt.title('Panel C: α / (1 - ρ) estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel C: α / (1 - ρ) estimates')

# %% [markdown]
# # 2. Step 2

# %% [markdown]
# ## DML ATEs

# %%
ate = {i: pd.read_csv(f'Estimates {i}x25\\step2_theta.csv') for i in obs}

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([ate[i].NL_theta_x for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(ate[i].NL_theta_x) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([ate[i].NL_XGB_theta_x for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(ate[i].NL_XGB_theta_x) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([(np.linalg.inv(np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ np.column_stack(((np.ones(10**3), np.linspace(0.1, 5, 10**3))))) @ (np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ (np.log(np.linspace(0.1, 5, 10**3)).reshape(-1,1) @ np.array(ate[i].NL_theta_log_x).reshape(1,-1))))[1,:] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean((np.linalg.inv(np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ np.column_stack(((np.ones(10**3), np.linspace(0.1, 5, 10**3))))) @ (np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ (np.log(np.linspace(0.1, 5, 10**3)).reshape(-1,1) @ np.array(ate[i].NL_theta_log_x).reshape(1,-1))))[1,:]) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline((np.linalg.inv(np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ np.column_stack(((np.ones(10**3), np.linspace(0.1, 5, 10**3))))) @ (np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ (np.log(np.linspace(0.1, 5, 10**3)).reshape(-1,1) * 1.5)))[1,:],
             color = 'darkblue',
             ls = 'dashed',
             linewidth = 3)

plt.axhline(0, color = 'grey', linewidth = 0.5)

plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{ATE}$')
plt.title('Panel B: $x^1$ ATE estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel B: $x^1$ ATE estimates')

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([ate[i].NL_theta_d for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(ate[i].NL_theta_d) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([ate[i].NL_XGB_theta_d for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(ate[i].NL_XGB_theta_d) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([ate[i].NL_theta_log_d for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(ate[i].NL_theta_log_d) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(2 * np.mean(np.log(np.linspace(0.1,5,10**3))) - 1, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.axhline(0, color = 'grey', linewidth = 0.5)

plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]],
           ['Linear model', 'Log model', 'Flexible model'],
           loc = 'lower right')
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{ATE}$')
plt.title('Panel A: $d$ ATE estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel A: $d$ ATE estimates')

# %% [markdown]
# ## GRF CATE

# %%
cate_x = {i: pd.read_csv(f'Estimates {i}x25\\step2_GRF_x.csv') for i in obs}

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([cate_x[i].to_numpy()[:,0:50].reshape(-1) for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(cate_x[i].to_numpy()[:,0:50].reshape(-1)) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'))
for patch in box1['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box2 = plt.boxplot([cate_x[i].to_numpy()[:,50:100].reshape(-1) for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(cate_x[i].to_numpy()[:,50:100].reshape(-1)) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'))
for patch in box2['boxes']:
    patch.set_facecolor('mediumpurple')
    patch.set_alpha(0.7)

[plt.axhline((np.linalg.inv(np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ np.column_stack(((np.ones(10**3), np.linspace(0.1, 5, 10**3))))) @ (np.column_stack((np.ones(10**3), np.linspace(0.1, 5, 10**3))).T @ (np.log(np.linspace(0.1, 5, 10**3)).reshape(-1,1) * i)))[1,:],
             color = 'darkblue', ls = 'dashed', linewidth = 3)
 for i in [1,2]]

plt.legend([box1['boxes'][0], box2['boxes'][0]], ['d = 0', 'd = 1'],
           loc = 'lower right')
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('$\hat{CATE}$')
plt.title('Panel B: $x^1$ CATE estimates', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel B: $x^1$ CATE estimates')

# %% [markdown]
# # 3. Elasticity RMSEs

# %%
lin = {i: pd.read_csv(f'Estimates {i}x25\\lin_RMSE.csv') for i in obs}
log = {i: pd.read_csv(f'Estimates {i}x25\\log_RMSE.csv') for i in obs}
xgb = {i: pd.read_csv(f'Estimates {i}x25\\xgb_RMSE.csv') for i in obs}

# %% [markdown]
# ## Own elasticities

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([lin[i].Own[~np.isnan(lin[i].Own)] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(lin[i].Own[~np.isnan(lin[i].Own)]) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([xgb[i].Own[~np.isnan(xgb[i].Own)] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(xgb[i].Own) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([log[i].Own for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(log[i].Own) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(0, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.ylim(top = 5.4)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('RMSE')
plt.title('Panel A: Own elasticity RMSE (mean = -4.623)', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel A: Own elasticity RMSE (mean = -4.623)')

# %% [markdown]
# ## Cross elasticities, same segment

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([lin[i]['Cross (same)'][~np.isnan(lin[i]['Cross (same)'])] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(lin[i]['Cross (same)'][~np.isnan(lin[i]['Cross (same)'])]) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([xgb[i]['Cross (same)'][~np.isnan(xgb[i]['Cross (same)'])] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(xgb[i]['Cross (same)']) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([log[i]['Cross (same)'] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(log[i]['Cross (same)']) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(0, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.ylim(top = 0.5)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('RMSE')
plt.title('Panel B: Same-segment cross elasticity RMSE (mean = 0.081)', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel B: Same-segment cross elasticity RMSE (mean = 0.081)')

# %% [markdown]
# ## Cross elasticities, different segment

# %%
fig, ax = plt.subplots(figsize=(15, 5))
box1 = plt.boxplot([lin[i]['Cross (different)'][~np.isnan(lin[i]['Cross (different)'])] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(lin[i]['Cross (different)'][~np.isnan(lin[i]['Cross (different)'])]) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box1['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

box2 = plt.boxplot([xgb[i]['Cross (different)'] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(xgb[i]['Cross (different)']) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box2['boxes']:
    patch.set_facecolor('lightgreen')
    patch.set_alpha(0.7)

box3 = plt.boxplot([log[i]['Cross (different)'] for i in obs],
                   whis = (2.5, 97.5),
                   showfliers = False,
                   patch_artist = True,
                   labels = [f'{i * 25:,}\n({i:,})' for i in obs],
                   #usermedians = np.array([np.mean(log[i]['Cross (different)']) for i in obs]),
                   medianprops = dict(linewidth = 2.5, color = 'black'),
                   widths = 0.7)
for patch in box3['boxes']:
    patch.set_facecolor('orange')
    patch.set_alpha(0.7)

plt.axhline(0, color = 'darkblue', ls = 'dashed', linewidth = 3)
plt.legend([box1['boxes'][0], box3['boxes'][0], box2['boxes'][0]], ['Linear model', 'Log model', 'Flexible model'])
plt.xlabel('Sample size\n(number of markets)')
plt.ylabel('RMSE')
plt.title('Panel C: Different-segment cross elasticity RMSE (mean = 0.033)', fontsize = 20, pad = 10)
# Out:
# Text(0.5, 1.0, 'Panel C: Different-segment cross elasticity RMSE (mean = 0.033)')
